# %%
"""Модуль посвящен второму уроку по гитхаб."""

# Алгоритм взаимодействия с чужим проектом на github

# 1. операция fork - это клонирование репозитория в свой личный аккаунт github

# 2. клонируем форкнутый репозиторий через кошку

# 3. выполняем в терминале команду pre-commit install,
# если после выполнения команды отображается не вот
#  это pre-commit installed at .git\hooks\pre-commit то я кладу файл
# pre-commit в корень и повторяю операцию
# (даже если есть всегда свой закидываем)

# 4. вносим правки в проект

# 5. фиксируем/отдать коммит (название коммита должно отображать
# что я в нем сделал)

# 6. нажимаем пуш в кошке

# 7. заходим в форкнутый репозиторий в github в интерет
# 8. нажимаем кнопку pullrequest, нажимаем зеленую кнопку, после нажимаем
# зеленую кнопку createpullrequest,
# после этого копируем ссылку сверху

# 9. пишем в чат teamprojects ссылку на pullrequest со словами примите пул

# 10. обновите ветки это значит зайти в личный аккаунт гитхаба
# и нажать кнопку synkfork

# 11. если требутеся добавить проект в окружение то надо нажать
# add folder to workspace.

# %% [markdown]
# ![image.png](attachment:image.png)
