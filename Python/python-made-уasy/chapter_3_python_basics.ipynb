# %%
"""Модуль посвящен третьей главе."""
# Out:
# 'Модуль посвящен третьей главе.'

# %% [markdown]
# 3.1 . Запуск Python

# %% [markdown]
# Настало время изучить основы языка программирования Python. Необходимо, чтобы вы проделывали самостоятельно все, что мы будем обсуждать. Для этого нужно
# открыть Spyder IDE или Jupyter Notebook.

# %% [markdown]
# Для создания этой книги я использовал Jupyter Notebook, и вы увидите сходство
# этой книги с оформлением документов. Jupyter Notebook - это хорошая отправная
# точка для начала обучения. Вы можете запускать свой код в ячейках кода и писать
# свой текст в ячейках Markdown.

# %% [markdown]
# 3.1.2. Использование Jupyter Notebook

# %% [markdown]
# Jupyter Notebook также входит в состав Anaconda, поэтому снова откройте окно
# Anaconda Navigator. Нажмите кнопку Launch под приложением Jupyter Notebook.
# Стартовое окно Jupyter Notebook откроется в браузере, который установлен по
# умолчанию (рис. 3.3).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чтобы создать документ Notebook, нажмите на кнопку New в правом верхнем углу
# и выберите пункт меню Python 3 (рис. 3 .3).

# %% [markdown]
# 3.2. Начнем с «Hello World!»

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# 3.3. Использование Python как калькулятора

# %% [markdown]
# Давайте попробуем выполнить несколько простых команд Python. Запустите Spyder
# IDE и введите приведенные ниже команды в редакторе. Сравните ваш вывод
# с моим выводом здесь и посмотрите, получите ли вы такие же результаты.

# %% [markdown]
# 3.3.1. Числа

# %% [markdown]
# Интерпретатор Python можно использовать как простой калькулятор: мы вводим
# в него выражение, а он возвращает значение. Синтаксис выражений прост: арифметические операторы +, -, * и / работают так же, как в любой компьютерной программе, которую вы могли использовать, например, в цифровом калькуляторе или
# электронной таблице Excel; круглые скобки (), как обычно, могут использоваться
# для группировки. Например:

# %%
2 + 2
# Out:
# 4

# %%
(50 - 5 * 6) / 4
# Out:
# 5.0

# %%
# результат деления всегда с плавающей точкой
8 / 5
# Out:
# 1.6

# %% [markdown]
# Целые числа (например, 2, 4, 20) имеют тип int, а числа с дробной частью (например, 5.0, 1 .6) имеют тип float. О числовых типах мы поговорим позднее.

# %% [markdown]
# Оператор деления / всегда возвращает float. Чтобы выполнить деление нацело и
# получить целочисленный результат (отбрасив дробную часть), вы можете использовать оператор //, а для вычисления остатка - оператор %.

# %%
# обычное деление с плавающей точкой
17 / 3
# Out:
# 5.666666666666667

# %%
# целочисленное деление
17 // 3
# Out:
# 5

# %%
# остаток от деления
17 % 3
# Out:
# 2

# %%
# проверка: результат * делитель + остаток
5 * 3 + 2
# Out:
# 17

# %% [markdown]
# Для вычисления степени можно использовать оператор **.

# %%
# 5 в квадрате
5**2
# Out:
# 25

# %%
# 2 в седьмой степени
2**7
# Out:
# 128

# %% [markdown]
# Знак равенства = используется для присвоения значения переменной. После присвоения результат не отображается:

# %%
# данный код ничего не возвращает
width = 20
height = 5 + 9

# %% [markdown]
# 3.3.2. Строки

# %% [markdown]
# Помимо чисел Python может также работать со строками, которые можно задавать
# несколькими способами. Они могут быть заключены в одинарные ' ... ' или двойные кавычки " ... ". Для экранирования кавычек используется символ \:

# %%
# одинарные ковычки
"python strings"
# Out:
# 'python strings'

# %%
# для экранирования кавычек используют \
# линтер сам поправляет палочку на кавычки
print("doesn't")
# Out:
# doesn't

# %%
# или двойные кавычки
print("doesn't")
# Out:
# doesn't

# %% [markdown]
# В интерактивном интерпретаторе строка вывода заключается в кавычки, а специальные символы экранированы обратной косой чертой. На вид такая строка отличается от ввода (сами кавычки могут быть другими), но эти две строки все равно
# эквивалентны. Строка заключается в двойные кавычки, если содержит внутри себя
# одинарные кавычки и не содержит двойных кавычек, в противном случае строка
# заключается в одинарные кавычки.

# %% [markdown]
# Функция print () позволяет получить более читаемый вывод, опустить кавычки
# и вывести экранированные и специальные символы:

# %% [markdown]
# Если вы не хотите, чтобы управляющие символы (такие как \n, \t) интерпретировались как специальные, вы можете использовать необработанные строки, добавив
# букву r перед первой кавычкой:

# %%
# здесь \n - переход на новую строку!
print("C:\\some\name")
# Out:
# C:\some
# ame

# %%
# r перед открывающейся кавычкой
print(r"C:\some\name")
# Out:
# C:\some\name

# %% [markdown]
# 3.3.2.1. Конкатенация и повторение

# %% [markdown]
# Строки можно объединять (склеивать) с помощью оператора + и повторять с помощью оператора *. Запомнить это просто. Оператор + складывает, а оператор *
# умножает.

# %%
"a" + "b"
# Out:
# 'ab'

# %%
"t" * 5
# Out:
# 'ttttt'

# %%
"no" * 3 + "dip"
# Out:
# 'nononodip'

# %% [markdown]
# Два или более строковых литерала (заключенных в кавычки строки), расположенных рядом друг с другом, автоматически объединяются.

# %%
print("nil", "abh")
# Out:
# nil abh

# %% [markdown]
# Это особенно удобно, если требуется разделить длинные строки.

# %%
# text = "put several strings within parentheses -"
# "- to have them joined together."
# print(text)

# %% [markdown]
# 3.3.2.2. Индексирование

# %% [markdown]
# Строки можно индексировать (обращаться к элементам строки по индексу), при
# этом первый символ имеет индекс О. Отдельного типа для данных символов не
# существует, т. к. символ - это просто строка длиной в один символ.

# %% [markdown]
# Например, для слова ' Python ' индексы будут такими:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В первой строке чисел указаны индексы букв в строке, а во второй строке - соответствующие отрицательные индексы.

# %%
# Символ в позиции 0
word = "Python"
word[0]
# Out:
# 'P'

# %%
word[5]
# Out:
# 'n'

# %% [markdown]
# Для отрицательных индексов отсчет ведется справа:

# %%
word[-4]
# Out:
# 't'

# %% [markdown]
# Обратите внимание: поскольку -О равняется О, то отрицательные индексы начинаются с -1.

# %% [markdown]
# 3.3.2.3. Срезы

# %% [markdown]
# Помимо индексирования строк также поддерживаются срезы. Если индексирование
# используется для извлечения отдельных символов, то срез возвращает подстроку.

# %%
# с позиции 0 (включительно) до 2 (не включая его)
word[0:2]
# Out:
# 'Py'

# %%
# с позиции 2 (включительно) до 5 (не включая его)
word[2:5]
# Out:
# 'tho'

# %% [markdown]
# Обратите внимание, что начальный индекс всегда включается, а конечный всегда
# исключается. Это гарантирует, что s[ : i]_ + s [i: J всегда равно s.

# %%
word[:2] + word[2:]
word[:4] + word[4:]
# Out:
# 'Python'

# %% [markdown]
# У срезов есть полезные значения по умолчанию для индексов. Опущенный первый
# индекс по умолчанию равен нулю, опущенный второй индекс по умолчанию равен
# длине строки.

# %% [markdown]
# Чтобы запомнить, как работают срезы, можно представить индексы как разделители между символами (рис. 3 .5), при этом левый край первого символа имеет номер О. Тогда правый край последнего символа строки из п символов имеет индекс п.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В первой строке чисел указано положение индексов от О до 6, во второй строке
# даны соответствующие отрицательные индексы. Срез строки от i до j состоит из
# всех символов между индексами i и j соответственно.

# %% [markdown]
# Строки Python нельзя изменить - они неизменяемы. Следовательно, присвоить
# новое значение символу по определенному индексу нельзя. Если вы попытаетесь
# это сделать, получите ошибку:

# %% [markdown]
# Если вам нужна новая строка, нужно ее создать.

# %%
# встроенная функция len() возвращает длину строки
len(word)
# Out:
# 6

# %%
s_: str = "supercalisfdhgfdh"
len(s_)
# Out:
# 17

# %% [markdown]
# 3.4. Синтаксис кода Python

# %% [markdown]
# 3.4.1. Выражения

# %% [markdown]
# Строки, написанные в исходном коде для выполнения, называются выражениями
# (рис. 3 .6), которые могут состоять из операторов разных типов, таких как оператор
# присваивания, условный оператор, оператор цикла и т. д. Все они нужны для того,
# чтобы пользователь мог получить нужный результат. Например, n = 20 - это выражение с оператором присваивания

# %% [markdown]
# Выражения могут быть однострочными или многострочными. Многострочные выражения можно переносить на другие строки с помощью круглых скобок (), квадратных [], обратной косой черты.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чтобы лучше понять приведенные выше понятия, рассмотрим примеры.

# %%
# перенос выражения на новую строку с использованием \
s_1: int = 1 + 2 + 3 + 4 + 5 + 6 + 7 + 8 + 9
print(s_1)
# Out:
# 45

# %%
# перенос выражения на новую строку с использованием ()
n_: int = 1 * 3 * 2 + 7 + 8 + 9
print(n_)
# Out:
# 30

# %%
# перенос выражения на новую строку с использованием []
footballer: list[str] = ["MESSI", "NEYMAR", "SUAREZ"]
print(footballer)
# Out:
# ['MESSI', 'NEYMAR', 'SUAREZ']

# %%
# перенос выражения на новую строку с использованием {}
x_: set[int] = {1 + 2 + 3 + 4 + 5 + 6 + 7 + 8 + 9}
print(x_)
# Out:
# {45}

# %% [markdown]
# Выражения - это строительные блоки любой программы. Это те самые действия,
# которые ваша программа должна выполнить. Нет выражений - нет и программы.
# Каждое выражение может состоять из ключевых слов, других выражений и операторов.

# %% [markdown]
# 3.4.1.1. Окончание выражений

# %% [markdown]
# В Python конец строки означает конец выражения. Но мы также рассмотрели, как
# написать выражение в нескольких строках.

# %% [markdown]
# Можно также завершить выражение с помощью точки с запятой (; ). Иногда за счет
# этого можно размещать нескольких выражений в одной строке, например:

# %%
flag: int = 2
ropes: int = 3
pole: int = 4
print(flag, ropes, pole)
# Out:
# 2 3 4

# %% [markdown]
# 3.4.2. Переменные и присваивание значений

# %% [markdown]
# Одна из самых мощных функциональностей любого языка программирования -
# это возможность работать с переменными. Переменная - это некоторое имя, связанное со значением. Обратите внимание, что переменная лишь ссылается на значение, которое ей присвоено, но не тоЖдественна ему. Когда переменной присваивается другое значение, старое присвоение сразу становится недействительным.

# %% [markdown]
# Оператор присваивания позволяет автоматически создавать новые переменные
# и присваивать им значения:

# %%
# переменной a_ присваиваем значение 45
# (указываем тип данных)
a_: int = 45
print(a_)
# присваиваем той же переменной другое значение
# a_: int = 2 + 3
# print(a_)
# мне оно не дает так сделать, нельзя писать одинаковыые переменные
# Out:
# 45

# %% [markdown]
# 3.4.3. Имена переменных и ключевые слова

# %% [markdown]
# Для переменных следует выбирать имена со смыслом, которые что-то говорят
# о хранимых данных. Например, при работе с данными о продажах магазина в выходные подойдет имя переменной Sales _ weekend.

# %% [markdown]
# Переменная не может использоваться несколько раз

# %% [markdown]
# Имена переменных могут быть любой длины и содержать как буквы, так и числа.

# %% [markdown]
# Писать имена можно в верхнем или нижнем регистре, но одно и то же имя с разными регистрами - это будут разные переменные, т. к. Python чувствителен к регистру. Существует еще несколько правил именования переменных.

# %% [markdown]
# ♦ Имя должно начинаться с буквы (не с цифры).

# %% [markdown]
# ♦ В имени может присутствовать символ подчеркивания _. Он используется для
# соединения слов в длинном имени переменной, т. к. пробелы использовать
# нельзя.

# %% [markdown]
# ♦ Нельзя использовать в качестве имен переменных ключевые слова Python:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Назначив переменной недопустимое имя, вы получите синтаксическую ошибку

# %% [markdown]
# 3.4.4. Выполнение выражений

# %% [markdown]
# Выражение - это совокупность значений, переменных и операторов. Когда вы
# вводите в командной строке выражение, интерпретатор вычисляет его и выводит
# результат.

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# Выражения могут содержать значения, переменные и операторы, но не обязательно
# все их сразу. Само по себе значение тоже считается выражением, как и отдельно
# взятая переменная

# %%
15
# Out:
# 15

# %% [markdown]
# Вычислить выражение - это не то же самое, что вывести его значение на экран.
# Покажем это на примере строки.

# %% [markdown]
# Когда интерпретатор Python выводит значение выражения, он использует тот же
# формат, который вы использовали бы для ввода значения. Для строк это означает,
# что будут выведены кавычки.

# %% [markdown]
# Но если вы используете функцию print (), Python
# отображает содержимое строки без кавычек.

# %% [markdown]
# 3.5. Первые шаги в программировании

# %% [markdown]
# Конечно, мы можем использовать Python для более сложных задач, чем сложение
# двух чисел. Например, можно вычислить начало ряда Фибоначчи следующим образом:

# %%
# ряд Фибонначи
# сумма двух элементов -- это следующий элемент ряда
a_1: int = 0
b_1: int = 1
while a_1 < 10:
    print(a_1)
    a_1, b_1 = b_1, a_1 + b_1
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# Давайте поэкспериментируем с этим простым кодом. Для начала изменим способ
# присвоения переменных а и ь. Значения будут такими же, но число строк сократится. Также изменим условие в цикле, чтобы показать, как оно влияет на результат

# %%
# тот же ряд Фибонначи
a_1, b_1 = 0, 1
while a_1 < 15:
    print(a_1)
    a_1, b_1 = b_1, a_1 + b_1
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %% [markdown]
# Вы заметили, что этот код работает так же, как и первый вариант? Кроме того,
# верхний предел для значения а теперь равен 1 5, и, следовательно, выводится еще
# ОДНО ЧИСЛО - 13.

# %% [markdown]
# В этом примере появилось сразу несколько новых выражений.

# %% [markdown]
# 1. В первой строке используется множественное присваивание: переменные а и ь
# одновременно получают значения о и 1. В последней строке кода это используется снова, причем здесь важно, что перед таким присваиванием всегда сначала
# вычисляется правая часть. Выражения в правой части вычисляются слева направо.

# %% [markdown]
# 2. Цикл while выполняется до тех пор, пока условие остается истинным (в первом
# варианте это было а < 10, которое мы позже изменили на а < 15). . В Python истинным является любое ненулевое целочисленное значение, ноль считается
# ложным. Стандартные операторы
# сравнения записываются привычным образом: < (меньше), > (больше), == (равно),
# <= (меньше или равно), >= (больше или равно) и ! = (не равно).

# %% [markdown]
# 3. Тело цикла записано с отступом. Огступы - это способ группировки выражений в Python. В интерактивном режиме интерпретатора для задания отступа
# нужно использовать табуляцию или пробелы. На практике код бывает гораздо
# более сложным, и у всех специализированных текстовых редакторов есть функция автоматического отступа. Когда составное выражение вводится в интерактивном режиме, за ним должна следовать пустая строка, указывающая на завершение (поскольку синтаксический анализатор не может угадать, когда блок кода
# закончился). Обратите внимание, что у всех строк в блоке должен быть одинаковый отступ.

# %% [markdown]
# 4. Функция print () выводит значение переданного аргумента на экран. Ее работа
# отличается от простого написания выражения в строке (как мы делали ранее),
# т. к. эта функция по-другому обрабатывает несколько аргументов, числа с плавающей запятой и строки. Строки выводятся без кавычек, а между аргументами
# вставляется пробел, что позволяет красиво форматировать результаты:

# %%
i_1: int = 256 * 256
print("The value of i_1 is", i_1)
# Out:
# The value of i_1 is 65536

# %% [markdown]
# 3.5.1 . Подробнее о функции print()

# %% [markdown]
# Фактический синтаксис функции print () выглядит так:

# %% [markdown]
# print ( *objects, sep= ' ', end= ' \n', file=sys.stdout, flush=False)

# %% [markdown]
# yа примере этого синтаксиса рассмотрим еще две важные концепции программирования на Python:

# %% [markdown]
# ♦ Аргументы (иногда обозначаемые словом args);

# %% [markdown]
# ♦ Именованные аргументы (иногда обозначаемые словом kwargs)

# %% [markdown]
# Аргументы - это все, что мы передаем в функцию. Например, в функцию print ()
# мы передавали строку или переменную - это и есть аргументы.

# %% [markdown]
# Если при определении функции вы хотите передавать ей больше одной переменной, но еще не знаете точно, сколько аргументов у вас будет, можно указать специальный синтаксис
# *args.

# %% [markdown]
# Символ * здесь означает, что мы можем передать функции любое количество
# переменных, а слово args - это своего рода стандартное соглашение, которое используется для лучшей читаемости кода. Можно использовать и любое другое слово, если оно будет достаточно значимым.

# %% [markdown]
# Как видите, в синтаксисе функции print ()
# вместо *args используется слово *objects.

# %% [markdown]
# Именованные аргументы - это аргументы, для которых при передаче в функцию
# указывается не только значение, но и имя.

# %% [markdown]
# Вы заметили в заголовке функции слова sep=, end=, file= и flush=? Это именованные
# аргументы, у них есть имя, а справа от символа = указано присвоенное им значение.

# %% [markdown]
# еперь, разобравшись с аргументами и именованными аргументами, давайте разберемся, что означает синтаксис print () и как с ним работать. Еще раз:

# %% [markdown]
# Параметры функции print () :

# %% [markdown]
# ♦ *objects - любое количество любых объектов. Перед выводом все объекты собираются в строку;

# %% [markdown]
# ♦ sep=' ' (необязательный) - задает разделитель объектов, если их несколько.
# Значение по умолчанию - символ пробела, указанный как ' ';

# %% [markdown]
# ♦ end= ' \n' (необязательный) - определяет, что вывести в конце строки. Значение
# по умолчанию - символ переноса строки ' \n' ;

# %% [markdown]
# ♦ file=sys. stdout (необязательный) - объект с методом write ( string) . Если этот
# параметр не указан, будет использоваться sys. stdout по умолчанию, что означает
# вывод результатов на экран;

# %% [markdown]
# ♦ flush=False (необязательный) - логическое значение, указывающее, будет ли
# вывод очищен (тrue) или буферизован (False). По умолчанию имеет значение
# False.

# %%
# тот же ряд Фибоначчи
a_1, b_1 = 0, 1
while a_1 < 15:
    print(a_1, end=", ")
    a_1, b_1 = b_1, a_1 + b_1
# Out:
# 0, 1, 1, 2, 3, 5, 8, 13,

# %% [markdown]
# 3.5.2. Форматированный вывод

# %% [markdown]
# И в продолжение темы, я хочу вас познакомить с удобным способом вывода
# результатов на экран.

# %%
a_2: int = 5
b_2: int = 6
a_2b_2: int = 5 * 6
print(f"when {a_2} is multiplied by {b_2}, the result is {a_2b_2}")
# Out:
# when 5 is multiplied by 6, the result is 30

# %%
# вариант со строками
name: str = "Nilabh"
lastname: str = "Nishchhat"
place: str = "Mumbai"
print(f"{name} {lastname} lives in {place.upper()}")
# Out:
# Nilabh Nishchhat lives in MUMBAI

# %% [markdown]
# 3.5.3. Простейшая геометрия и print()

# %% [markdown]
# Мы рассмотрели использование функции print () и ее синтаксис. Нарисуем треугольник, используя только базовый код.

# %%
print("    /|")
print("   / |")
print("  /  |")
print(" /___|")
# Out:
#     /|
#    / |
#   /  |
#  /___|

# %% [markdown]
# Это простейший способ вывода фигур. В следующих главах, когда мы узнаем
# о циклах и условных операторах, мы нарисуем несколько других фигур, а заодно
# узнаем, как работают циклы.
