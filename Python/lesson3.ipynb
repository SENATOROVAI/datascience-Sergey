# %%
"""Модуль по работе в гитхаб."""

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# если у нас после нажатия кнопку pull появляется кнопка stah это значит что есть конфликт файлов, таким образом разработчик работает и я работаем в одном файле,
# для того что бы принять изминения с гитхаба, нужно добавить мои файлы в буфер обмена - то есть в stash. после того как я добавил в stah и принял pull нужно stash восстановить
# с помощью кнопки restore

# %% [markdown]
# заходим в файл который конфликтует, мы найдем его с помощью иконки "!" и выбераем либо "accept currant changes" - зеленая часть либо accept incumming changes - синяя часть
# для экстремалов можно устранять руками
